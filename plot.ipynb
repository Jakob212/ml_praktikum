# %% [markdown]
# Random Forest 100 Trees

# %%
import matplotlib.pyplot as plt
import numpy as np

# Python - WEKA Ergebnisse
weka_build_times = np.array([0.84611702, 0.47737217, 0.37609601, 0.36891961, 0.3804636, 0.35499144,
                             0.39613819, 0.37833309, 0.37393522, 0.36926889])
weka_evaluate_times = np.array([0.16004443, 0.13996053, 0.19094801, 0.17208815, 0.19006944, 0.14904475,
                                0.12917066, 0.16304278, 0.16303301, 0.18009448])
weka_accuracies = np.array([0.63741786, 0.64321608, 0.63355238, 0.64398918, 0.6490143, 0.63780441,
                            0.64437572, 0.64553537, 0.63703131, 0.63007344])

# Scikit-Learn Ergebnisse
sklearn_build_times = np.array([0.38863659, 0.35514522, 0.35697985, 0.3656733, 0.35609889, 0.3528266,
                                0.37509656, 0.36005664, 0.3426609, 0.33834624])
sklearn_evaluate_times = np.array([0.02842355, 0.0254097, 0.02718568, 0.02577806, 0.02510595, 0.02578998,
                                   0.02505445, 0.02609372, 0.02426958, 0.02602243])
sklearn_accuracies = np.array([0.63239273, 0.63277928, 0.65597217, 0.64630847, 0.62388867, 0.63509857,
                               0.63741786, 0.64166989, 0.62736761, 0.63548512])

# WEKA
additional_accuracies = np.array([0.643216, 0.633939, 0.623889, 0.643603, 0.641283,
                                  0.636258, 0.638191, 0.649401, 0.64051, 0.64051])
additional_build_times = np.array([0.63, 0.5, 0.47, 0.47, 0.5, 0.48, 0.47, 0.51, 0.48, 0.49])
additional_evaluate_times = np.array([0.18, 0.24, 0.17, 0.21, 0.34, 0.21, 0.23, 0.2, 0.2, 0.31])

# Scatter plot for build times vs accuracy with consistent markers
plt.figure(figsize=(10, 6))
plt.scatter(weka_build_times, weka_accuracies, color='purple', label='Python Weka Wrapper', marker='o')
plt.scatter(sklearn_build_times, sklearn_accuracies, color='orange', label='Scikit-Learn', marker='o')
plt.scatter(additional_build_times, additional_accuracies, color='blue', label='WEKA', marker='o')

plt.title('Accuracy vs Build Time')
plt.xlabel('Build Time (seconds)')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Scatter plot for evaluate times vs accuracy with consistent markers
plt.figure(figsize=(10, 6))
plt.scatter(weka_evaluate_times, weka_accuracies, color='purple', label='Python Weka Wrapper', marker='o')
plt.scatter(sklearn_evaluate_times, sklearn_accuracies, color='orange', label='Scikit-Learn', marker='o')
plt.scatter(additional_evaluate_times, additional_accuracies, color='blue', label='WEKA', marker='o')

plt.title('Accuracy vs Evaluate Time')
plt.xlabel('Evaluate Time (seconds)')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Random Forest 250 Trees

# %%
import matplotlib.pyplot as plt
import numpy as np

# New dataset for Python Weka wrapper results
weka_wrapper_build_times = np.array([1.54386497, 0.95116854, 0.90725946, 0.93792844, 0.93851352,
                                     0.99440813, 0.93779278, 0.97991967, 0.93467951, 0.89921522])
weka_wrapper_evaluate_times = np.array([0.65305376, 0.5631237, 0.48705626, 0.55999804, 0.54599595,
                                        0.6042645, 0.59438372, 0.60597992, 0.55473661, 0.54014897])
weka_wrapper_accuracies = np.array([0.64514882, 0.64437572, 0.64824121, 0.65056049, 0.65056049,
                                    0.63664476, 0.64862775, 0.65597217, 0.63239273, 0.62388867])

# Scikit-Learn results (already provided again for comparison)
sklearn_build_times = np.array([0.95044351, 0.85604191, 0.85919404, 0.87604022, 0.85810757,
                                0.85887909, 0.8578198, 0.85297894, 0.83590055, 0.842314])
sklearn_evaluate_times = np.array([0.05595541, 0.06198668, 0.05432224, 0.05699754, 0.05700135,
                                   0.06400013, 0.05571461, 0.05844927, 0.05634522, 0.05624962])
sklearn_accuracies = np.array([0.64089679, 0.64940085, 0.66486278, 0.6393506, 0.63741786,
                               0.64128334, 0.6393506, 0.65829146, 0.64051024, 0.64630847])



# New dataset for WEKA with 250 trees, 8 numExecutionSlots
weka_250_build_times = np.array([1.15, 1.25, 1.14, 1.12, 1.13, 1.16, 1.19, 1.16, 1.18, 1.17])
weka_250_evaluate_times = np.array([0.54, 0.52, 0.53, 0.56, 0.5, 0.44, 0.56, 0.44, 0.41, 0.58])
weka_250_accuracies = np.array([0.644376, 0.645149, 0.638191, 0.650947, 0.647855,
                                0.647855, 0.645922, 0.643216, 0.650947, 0.648628])

# Scatter plot for build times vs accuracy with extended scale
plt.figure(figsize=(10, 6))
plt.scatter(weka_wrapper_build_times, weka_wrapper_accuracies, color='purple', label='Python Weka Wrapper', marker='o')
plt.scatter(sklearn_build_times, sklearn_accuracies, color='orange', label='Scikit-Learn', marker='o')
plt.scatter(weka_250_build_times, weka_250_accuracies, color='blue', label='WEKA', marker='o')

plt.title('Accuracy vs Build Time')
plt.xlabel('Build Time (seconds)')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.xlim(0.3, 1.6)  # Extending the x-axis scale to better display differences
plt.ylim(0.62, 0.66)  # Slightly extending the y-axis for better visualization
plt.show()

# Scatter plot for evaluate times vs accuracy with extended scale
plt.figure(figsize=(10, 6))
plt.scatter(weka_wrapper_evaluate_times, weka_wrapper_accuracies, color='purple', label='Weka Wrapper', marker='o')
plt.scatter(sklearn_evaluate_times, sklearn_accuracies, color='orange', label='Scikit-Learn', marker='o')
plt.scatter(weka_250_evaluate_times, weka_250_accuracies, color='blue', label='WEKA', marker='o')

plt.title('Accuracy vs Evaluate Time')
plt.xlabel('Evaluate Time (seconds)')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.xlim(0.02, 0.7)  # Extending the x-axis scale to better display differences
plt.ylim(0.62, 0.66)  # Slightly extending the y-axis for better visualization
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Python Weka Wrapper KNN results
weka_wrapper_build_times = np.array([0.00122058, 0.00189829, 0.0029974, 0.00129982, 0.00199866,
                                     0.00195885, 0.00200009, 0.00199604, 0.00100112, 0.00209332])
weka_wrapper_evaluate_times = np.array([0.91033936, 0.84051657, 0.85721016, 0.7825923, 0.84136033,
                                        0.86428952, 0.89442158, 0.93312693, 0.87348723, 0.92778635])
weka_wrapper_accuracies = np.array([0.57595671, 0.56938539, 0.57866254, 0.58214148, 0.58175493,
                                    0.57474681, 0.58861229, 0.5775029, 0.57093158, 0.57170468])

# Scikit-learn KNN results
sklearn_knn_build_times = np.array([0.00299621, 0.00200105, 0.0030005, 0.00399756, 0.00300097,
                                    0.00300002, 0.00199699, 0.0030005, 0.00200129, 0.00300002])
sklearn_knn_evaluate_times = np.array([0.17831731, 0.1400044, 0.11099887, 0.13601494, 0.10998273,
                                       0.15901518, 0.11598349, 0.15501475, 0.11098242, 0.13800049])
sklearn_knn_accuracies = np.array([0.56745265, 0.55353692, 0.56049478, 0.56474681, 0.55392346,
                                   0.55856204, 0.55276382, 0.53807499, 0.55508311, 0.55005798])

# WEKA KNN results
weka_knn_build_times = np.zeros(10)  # Build times are 0 as per data
weka_knn_evaluate_times = np.array([0.71, 0.64, 0.64, 0.63, 0.64, 0.63, 0.64, 0.64, 0.64, 0.63])
weka_knn_accuracies = np.array([0.569385, 0.578663, 0.582141, 0.581755, 0.564747,
                                0.568612, 0.571705, 0.577503, 0.570932, 0.570158])

# Scatter plot for build times vs accuracy
plt.figure(figsize=(10, 6))
plt.scatter(weka_wrapper_build_times, weka_wrapper_accuracies, color='purple', label='Python Weka Wrapper', marker='o')
plt.scatter(sklearn_knn_build_times, sklearn_knn_accuracies, color='orange', label='Scikit-learn', marker='o')
plt.scatter(weka_knn_build_times, weka_knn_accuracies, color='blue', label='WEKA', marker='o')

plt.title('Accuracy vs Build Time (KNN)')
plt.xlabel('Build Time (seconds)')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.xlim(0, 0.005)  # Adjusted for small build times
plt.ylim(0.53, 0.59)  # Adjusted for accuracy range
plt.show()

# Scatter plot for evaluate times vs accuracy
plt.figure(figsize=(10, 6))
plt.scatter(weka_wrapper_evaluate_times, weka_wrapper_accuracies, color='purple', label='Python Weka Wrapper', marker='o')
plt.scatter(sklearn_knn_evaluate_times, sklearn_knn_accuracies, color='orange', label='Scikit-learn', marker='o')
plt.scatter(weka_knn_evaluate_times, weka_knn_accuracies, color='blue', label='WEKA', marker='o')

plt.title('Accuracy vs Evaluate Time (KNN)')
plt.xlabel('Evaluate Time (seconds)')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.xlim(0.1, 0.95)  # Adjusted for evaluate time range
plt.ylim(0.53, 0.59)  # Adjusted for accuracy range
plt.show()
