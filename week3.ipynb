# %%
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# 1. Load data
print("Loading data...")
data_path = "dataset/clf_num/jannis.csv"

data = pd.read_csv(data_path)

# 2. Preprocess data
# Assuming the last column is the target variable
X = data.iloc[:, :-1].values  # Features
y = data.iloc[:, -1].values   # Target

# Convert target to nominal if it's numeric
if np.issubdtype(y.dtype, np.number):
    y = y.astype(int)

print(f"Data loaded: {X.shape[0]} instances, {X.shape[1]} attributes.")

# 3. Parameters
n_experiments = 100
build_times = []
evaluate_times = []
accuracies = []

# 4. Perform 100 randomized experiments
print("\nPerforming 100 randomized experiments...")
for experiment in range(n_experiments):
    print(f"\nExperiment {experiment + 1} of {n_experiments}")

    # 4.1 Randomly split the data into 66% train and 34% test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.34, random_state=experiment)

    # 4.2 Create and train Random Forest model
    rf = RandomForestClassifier(n_estimators=100, max_depth=None, n_jobs=-1, random_state=experiment)

    start_build = time.time()
    rf.fit(X_train, y_train)
    end_build = time.time()
    build_time = end_build - start_build
    build_times.append(build_time)

    # 4.3 Evaluate the model
    start_evaluate = time.time()
    y_pred = rf.predict(X_test)
    end_evaluate = time.time()
    evaluate_time = end_evaluate - start_evaluate
    evaluate_times.append(evaluate_time)

    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

    print(f"Accuracy: {accuracy * 100:.2f}%")
    print(f"Training time: {build_time:.4f} seconds")
    print(f"Evaluation time: {evaluate_time:.4f} seconds")

# 5. Output Results
print("\nResults of 100 Experiments:")
print(f"Training times (seconds): {', '.join(f'{time:.4f}' for time in build_times)}")
print(f"Evaluation times (seconds): {', '.join(f'{time:.4f}' for time in evaluate_times)}")
print(f"Accuracies (%): {', '.join(f'{accuracy * 100:.2f}' for accuracy in accuracies)}")

# Calculate and display averages
print("\nAverage Training Time: {:.4f} seconds".format(np.mean(build_times)))
print("Average Evaluation Time: {:.4f} seconds".format(np.mean(evaluate_times)))
print("Average Accuracy: {:.2f}%".format(np.mean(accuracies) * 100))
# Out:
# Loading data...
# Data loaded: 57580 instances, 54 attributes.
#
# Performing 100 randomized experiments...
#
# Experiment 1 of 100
# Accuracy: 78.02%
# Training time: 6.6663 seconds
# Evaluation time: 0.0899 seconds
#
# Experiment 2 of 100
# Accuracy: 78.32%
# Training time: 5.0263 seconds
# Evaluation time: 0.0885 seconds
#
# Experiment 3 of 100
# Accuracy: 78.14%
# Training time: 5.1627 seconds
# Evaluation time: 0.0671 seconds
#
# Experiment 4 of 100
# Accuracy: 78.32%
# Training time: 5.2655 seconds
# Evaluation time: 0.0863 seconds
#
# Experiment 5 of 100
# Accuracy: 78.16%
# Training time: 7.1076 seconds
# Evaluation time: 0.1678 seconds
#
# Experiment 6 of 100
# Accuracy: 78.12%
# Training time: 10.2399 seconds
# Evaluation time: 0.1610 seconds
#
# Experiment 7 of 100
# Accuracy: 78.46%
# Training time: 6.4080 seconds
# Evaluation time: 0.1093 seconds
#
# Experiment 8 of 100
# Accuracy: 78.17%
# Training time: 7.7707 seconds
# Evaluation time: 0.1800 seconds
#
# Experiment 9 of 100
# Accuracy: 78.31%
# Training time: 7.3479 seconds
# Evaluation time: 0.0830 seconds
#
# Experiment 10 of 100
# Accuracy: 78.35%
# Training time: 7.8591 seconds
# Evaluation time: 0.0932 seconds
#
# Experiment 11 of 100
# Accuracy: 78.66%
# Training time: 7.9660 seconds
# Evaluation time: 0.0761 seconds
#
# Experiment 12 of 100
# Accuracy: 78.03%
# Training time: 7.9777 seconds
# Evaluation time: 0.0840 seconds
#
# Experiment 13 of 100
# Accuracy: 78.14%
# Training time: 7.9710 seconds
# Evaluation time: 0.0763 seconds
#
# Experiment 14 of 100
# Accuracy: 78.29%
# Training time: 8.2611 seconds
# Evaluation time: 0.0849 seconds
#
# Experiment 15 of 100
# Accuracy: 78.17%
# Training time: 7.3442 seconds
# Evaluation time: 0.0879 seconds
#
# Experiment 16 of 100
# Accuracy: 78.46%
# Training time: 7.9135 seconds
# Evaluation time: 0.0833 seconds
#
# Experiment 17 of 100
# Accuracy: 78.30%
# Training time: 8.2981 seconds
# Evaluation time: 0.0883 seconds
#
# Experiment 18 of 100
# Accuracy: 78.51%
# Training time: 8.8266 seconds
# Evaluation time: 0.0906 seconds
#
# Experiment 19 of 100
# Accuracy: 78.25%
# Training time: 8.9716 seconds
# Evaluation time: 0.1154 seconds
#
# Experiment 20 of 100
# Accuracy: 78.09%
# Training time: 9.4872 seconds
# Evaluation time: 0.0878 seconds
#
# Experiment 21 of 100
# Accuracy: 77.89%
# Training time: 11.3540 seconds
# Evaluation time: 0.1051 seconds
#
# Experiment 22 of 100
# Accuracy: 78.52%
# Training time: 12.2428 seconds
# Evaluation time: 0.1062 seconds
#
# Experiment 23 of 100
# Accuracy: 78.55%
# Training time: 14.8455 seconds
# Evaluation time: 0.1119 seconds
#
# Experiment 24 of 100
# Accuracy: 78.10%
# Training time: 14.7438 seconds
# Evaluation time: 0.1312 seconds
#
# Experiment 25 of 100
# Accuracy: 78.04%
# Training time: 18.4264 seconds
# Evaluation time: 0.1839 seconds
#
# Experiment 26 of 100
# Accuracy: 78.13%
# Training time: 13.2497 seconds
# Evaluation time: 0.1643 seconds
#
# Experiment 27 of 100
# Accuracy: 78.25%
# Training time: 11.4909 seconds
# Evaluation time: 0.1274 seconds
#
# Experiment 28 of 100
# Accuracy: 78.23%
# Training time: 11.8872 seconds
# Evaluation time: 0.1335 seconds
#
# Experiment 29 of 100
# Accuracy: 77.77%
# Training time: 9.8535 seconds
# Evaluation time: 0.0917 seconds
#
# Experiment 30 of 100
# Accuracy: 78.40%
# Training time: 7.9899 seconds
# Evaluation time: 0.0899 seconds
#
# Experiment 31 of 100
# Accuracy: 78.48%
# Training time: 7.9452 seconds
# Evaluation time: 0.0871 seconds
#
# Experiment 32 of 100
# Accuracy: 77.80%
# Training time: 8.5877 seconds
# Evaluation time: 0.0899 seconds
#
# Experiment 33 of 100
# Accuracy: 78.24%
# Training time: 9.1280 seconds
# Evaluation time: 0.0771 seconds
#
# Experiment 34 of 100
# Accuracy: 78.11%
# Training time: 9.1968 seconds
# Evaluation time: 0.1021 seconds
#
# Experiment 35 of 100
# Accuracy: 78.42%
# Training time: 9.9521 seconds
# Evaluation time: 0.1015 seconds
#
# Experiment 36 of 100
# Accuracy: 78.24%
# Training time: 10.7677 seconds
# Evaluation time: 0.1048 seconds
#
# Experiment 37 of 100
# Accuracy: 78.16%
# Training time: 11.5927 seconds
# Evaluation time: 0.1059 seconds
#
# Experiment 38 of 100
# Accuracy: 77.91%
# Training time: 13.7042 seconds
# Evaluation time: 0.1191 seconds
#
# Experiment 39 of 100
# Accuracy: 78.32%
# Training time: 12.2012 seconds
# Evaluation time: 0.1088 seconds
#
# Experiment 40 of 100
# Accuracy: 78.04%
# Training time: 12.8968 seconds
# Evaluation time: 0.0962 seconds
#
# Experiment 41 of 100
# Accuracy: 78.23%
# Training time: 11.8259 seconds
# Evaluation time: 0.0870 seconds
#
# Experiment 42 of 100
# Accuracy: 78.20%
# Training time: 9.5860 seconds
# Evaluation time: 0.0833 seconds
#
# Experiment 43 of 100
# Accuracy: 78.15%
# Training time: 8.9780 seconds
# Evaluation time: 0.0889 seconds
#
# Experiment 44 of 100
# Accuracy: 77.97%
# Training time: 8.2691 seconds
# Evaluation time: 0.0910 seconds
#
# Experiment 45 of 100
# Accuracy: 78.04%
# Training time: 8.1248 seconds
# Evaluation time: 0.0832 seconds
#
# Experiment 46 of 100
# Accuracy: 77.84%
# Training time: 7.7138 seconds
# Evaluation time: 0.0897 seconds
#
# Experiment 47 of 100
# Accuracy: 78.19%
# Training time: 7.9349 seconds
# Evaluation time: 0.0834 seconds
#
# Experiment 48 of 100
# Accuracy: 78.30%
# Training time: 7.3483 seconds
# Evaluation time: 0.0752 seconds
#
# Experiment 49 of 100
# Accuracy: 78.12%
# Training time: 7.3048 seconds
# Evaluation time: 0.0856 seconds
#
# Experiment 50 of 100
# Accuracy: 78.36%
# Training time: 7.4777 seconds
# Evaluation time: 0.0839 seconds
#
# Experiment 51 of 100
# Accuracy: 78.26%
# Training time: 8.2182 seconds
# Evaluation time: 0.0902 seconds
#
# Experiment 52 of 100
# Accuracy: 77.87%
# Training time: 8.0115 seconds
# Evaluation time: 0.0761 seconds
#
# Experiment 53 of 100
# Accuracy: 77.68%
# Training time: 8.6154 seconds
# Evaluation time: 0.1037 seconds
#
# Experiment 54 of 100
# Accuracy: 77.90%
# Training time: 8.9520 seconds
# Evaluation time: 0.0809 seconds
#
# Experiment 55 of 100
# Accuracy: 77.93%
# Training time: 9.4847 seconds
# Evaluation time: 0.0872 seconds
#
# Experiment 56 of 100
# Accuracy: 78.14%
# Training time: 10.1395 seconds
# Evaluation time: 0.0946 seconds
#
# Experiment 57 of 100
# Accuracy: 78.13%
# Training time: 10.6372 seconds
# Evaluation time: 0.1076 seconds
#
# Experiment 58 of 100
# Accuracy: 78.54%
# Training time: 12.6188 seconds
# Evaluation time: 0.1220 seconds
#
# Experiment 59 of 100
# Accuracy: 78.07%
# Training time: 15.4233 seconds
# Evaluation time: 0.1186 seconds
#
# Experiment 60 of 100
# Accuracy: 78.53%
# Training time: 14.7090 seconds
# Evaluation time: 0.1181 seconds
#
# Experiment 61 of 100
# Accuracy: 78.05%
# Training time: 11.3290 seconds
# Evaluation time: 0.0956 seconds
#
# Experiment 62 of 100
# Accuracy: 78.00%
# Training time: 10.8690 seconds
# Evaluation time: 0.1021 seconds
#
# Experiment 63 of 100
# Accuracy: 77.80%
# Training time: 9.4003 seconds
# Evaluation time: 0.0897 seconds
#
# Experiment 64 of 100
# Accuracy: 78.51%
# Training time: 9.7977 seconds
# Evaluation time: 0.0981 seconds
#
# Experiment 65 of 100
# Accuracy: 78.19%
# Training time: 9.6767 seconds
# Evaluation time: 0.0833 seconds
#
# Experiment 66 of 100
# Accuracy: 77.99%
# Training time: 8.9237 seconds
# Evaluation time: 0.0915 seconds
#
# Experiment 67 of 100
# Accuracy: 78.62%
# Training time: 8.0582 seconds
# Evaluation time: 0.0920 seconds
#
# Experiment 68 of 100
# Accuracy: 78.19%
# Training time: 7.6450 seconds
# Evaluation time: 0.0978 seconds
#
# Experiment 69 of 100
# Accuracy: 77.71%
# Training time: 7.2806 seconds
# Evaluation time: 0.0841 seconds
#
# Experiment 70 of 100
# Accuracy: 78.35%
# Training time: 7.2452 seconds
# Evaluation time: 0.0750 seconds
#
# Experiment 71 of 100
# Accuracy: 77.72%
# Training time: 7.2580 seconds
# Evaluation time: 0.0796 seconds
#
# Experiment 72 of 100
# Accuracy: 78.34%
# Training time: 8.4511 seconds
# Evaluation time: 0.0770 seconds
#
# Experiment 73 of 100
# Accuracy: 78.77%
# Training time: 12.6492 seconds
# Evaluation time: 0.1821 seconds
#
# Experiment 74 of 100
# Accuracy: 78.12%
# Training time: 13.8531 seconds
# Evaluation time: 0.1663 seconds
#
# Experiment 75 of 100
# Accuracy: 78.47%
# Training time: 12.6279 seconds
# Evaluation time: 0.1670 seconds
#
# Experiment 76 of 100
# Accuracy: 78.12%
# Training time: 12.8151 seconds
# Evaluation time: 0.1795 seconds
#
# Experiment 77 of 100
# Accuracy: 78.47%
# Training time: 17.3284 seconds
# Evaluation time: 0.2510 seconds
#
# Experiment 78 of 100
# Accuracy: 77.99%
# Training time: 19.5613 seconds
# Evaluation time: 0.2657 seconds
#
# Experiment 79 of 100
# Accuracy: 77.90%
# Training time: 15.5259 seconds
# Evaluation time: 0.1311 seconds
#
# Experiment 80 of 100
# Accuracy: 77.83%
# Training time: 12.0687 seconds
# Evaluation time: 0.1120 seconds
#
# Experiment 81 of 100
# Accuracy: 77.83%
# Training time: 13.9064 seconds
# Evaluation time: 0.1104 seconds
#
# Experiment 82 of 100
# Accuracy: 78.08%
# Training time: 12.7801 seconds
# Evaluation time: 0.0980 seconds
#
# Experiment 83 of 100
# Accuracy: 78.07%
# Training time: 9.4063 seconds
# Evaluation time: 0.0898 seconds
#
# Experiment 84 of 100
# Accuracy: 78.50%
# Training time: 10.0872 seconds
# Evaluation time: 0.0941 seconds
#
# Experiment 85 of 100
# Accuracy: 77.57%
# Training time: 9.0112 seconds
# Evaluation time: 0.0787 seconds
#
# Experiment 86 of 100
# Accuracy: 78.17%
# Training time: 10.6994 seconds
# Evaluation time: 0.1798 seconds
#
# Experiment 87 of 100
# Accuracy: 78.51%
# Training time: 10.1959 seconds
# Evaluation time: 0.1287 seconds
#
# Experiment 88 of 100
# Accuracy: 78.15%
# Training time: 11.0982 seconds
# Evaluation time: 0.1699 seconds
#
# Experiment 89 of 100
# Accuracy: 78.55%
# Training time: 12.1078 seconds
# Evaluation time: 0.1202 seconds
#
# Experiment 90 of 100
# Accuracy: 78.16%
# Training time: 12.9650 seconds
# Evaluation time: 0.1765 seconds
#
# Experiment 91 of 100
# Accuracy: 78.41%
# Training time: 14.5241 seconds
# Evaluation time: 0.1446 seconds
#
# Experiment 92 of 100
# Accuracy: 77.96%
# Training time: 16.0679 seconds
# Evaluation time: 0.1160 seconds
#
# Experiment 93 of 100
# Accuracy: 78.09%
# Training time: 17.5486 seconds
# Evaluation time: 0.1248 seconds
#
# Experiment 94 of 100
# Accuracy: 78.58%
# Training time: 16.8452 seconds
# Evaluation time: 0.1048 seconds
#
# Experiment 95 of 100
# Accuracy: 78.88%
# Training time: 13.3174 seconds
# Evaluation time: 0.1574 seconds
#
# Experiment 96 of 100
# Accuracy: 77.93%
# Training time: 16.7808 seconds
# Evaluation time: 0.1822 seconds
#
# Experiment 97 of 100
# Accuracy: 78.30%
# Training time: 10.2747 seconds
# Evaluation time: 0.0857 seconds
#
# Experiment 98 of 100
# Accuracy: 78.13%
# Training time: 8.5327 seconds
# Evaluation time: 0.0949 seconds
#
# Experiment 99 of 100
# Accuracy: 78.32%
# Training time: 8.4586 seconds
# Evaluation time: 0.0808 seconds
#
# Experiment 100 of 100
# Accuracy: 77.81%
# Training time: 7.5339 seconds
# Evaluation time: 0.0883 seconds
#
# Results of 100 Experiments:
# Training times (seconds): 6.6663, 5.0263, 5.1627, 5.2655, 7.1076, 10.2399, 6.4080, 7.7707, 7.3479, 7.8591, 7.9660, 7.9777, 7.9710, 8.2611, 7.3442, 7.9135, 8.2981, 8.8266, 8.9716, 9.4872, 11.3540, 12.2428, 14.8455, 14.7438, 18.4264, 13.2497, 11.4909, 11.8872, 9.8535, 7.9899, 7.9452, 8.5877, 9.1280, 9.1968, 9.9521, 10.7677, 11.5927, 13.7042, 12.2012, 12.8968, 11.8259, 9.5860, 8.9780, 8.2691, 8.1248, 7.7138, 7.9349, 7.3483, 7.3048, 7.4777, 8.2182, 8.0115, 8.6154, 8.9520, 9.4847, 10.1395, 10.6372, 12.6188, 15.4233, 14.7090, 11.3290, 10.8690, 9.4003, 9.7977, 9.6767, 8.9237, 8.0582, 7.6450, 7.2806, 7.2452, 7.2580, 8.4511, 12.6492, 13.8531, 12.6279, 12.8151, 17.3284, 19.5613, 15.5259, 12.0687, 13.9064, 12.7801, 9.4063, 10.0872, 9.0112, 10.6994, 10.1959, 11.0982, 12.1078, 12.9650, 14.5241, 16.0679, 17.5486, 16.8452, 13.3174, 16.7808, 10.2747, 8.5327, 8.4586, 7.5339
# Evaluation times (seconds): 0.0899, 0.0885, 0.0671, 0.0863, 0.1678, 0.1610, 0.1093, 0.1800, 0.0830, 0.0932, 0.0761, 0.0840, 0.0763, 0.0849, 0.0879, 0.0833, 0.0883, 0.0906, 0.1154, 0.0878, 0.1051, 0.1062, 0.1119, 0.1312, 0.1839, 0.1643, 0.1274, 0.1335, 0.0917, 0.0899, 0.0871, 0.0899, 0.0771, 0.1021, 0.1015, 0.1048, 0.1059, 0.1191, 0.1088, 0.0962, 0.0870, 0.0833, 0.0889, 0.0910, 0.0832, 0.0897, 0.0834, 0.0752, 0.0856, 0.0839, 0.0902, 0.0761, 0.1037, 0.0809, 0.0872, 0.0946, 0.1076, 0.1220, 0.1186, 0.1181, 0.0956, 0.1021, 0.0897, 0.0981, 0.0833, 0.0915, 0.0920, 0.0978, 0.0841, 0.0750, 0.0796, 0.0770, 0.1821, 0.1663, 0.1670, 0.1795, 0.2510, 0.2657, 0.1311, 0.1120, 0.1104, 0.0980, 0.0898, 0.0941, 0.0787, 0.1798, 0.1287, 0.1699, 0.1202, 0.1765, 0.1446, 0.1160, 0.1248, 0.1048, 0.1574, 0.1822, 0.0857, 0.0949, 0.0808, 0.0883
# Accuracies (%): 78.02, 78.32, 78.14, 78.32, 78.16, 78.12, 78.46, 78.17, 78.31, 78.35, 78.66, 78.03, 78.14, 78.29, 78.17, 78.46, 78.30, 78.51, 78.25, 78.09, 77.89, 78.52, 78.55, 78.10, 78.04, 78.13, 78.25, 78.23, 77.77, 78.40, 78.48, 77.80, 78.24, 78.11, 78.42, 78.24, 78.16, 77.91, 78.32, 78.04, 78.23, 78.20, 78.15, 77.97, 78.04, 77.84, 78.19, 78.30, 78.12, 78.36, 78.26, 77.87, 77.68, 77.90, 77.93, 78.14, 78.13, 78.54, 78.07, 78.53, 78.05, 78.00, 77.80, 78.51, 78.19, 77.99, 78.62, 78.19, 77.71, 78.35, 77.72, 78.34, 78.77, 78.12, 78.47, 78.12, 78.47, 77.99, 77.90, 77.83, 77.83, 78.08, 78.07, 78.50, 77.57, 78.17, 78.51, 78.15, 78.55, 78.16, 78.41, 77.96, 78.09, 78.58, 78.88, 77.93, 78.30, 78.13, 78.32, 77.81
#
# Average Training Time: 10.3981 seconds
# Average Evaluation Time: 0.1104 seconds
# Average Accuracy: 78.19%
